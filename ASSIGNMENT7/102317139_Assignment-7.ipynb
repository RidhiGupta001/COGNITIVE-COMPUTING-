# %% [markdown]
# **Ques 1**

# %%
import numpy as np
import pandas as pd

roll_number = 102317139
np.random.seed(roll_number)

# %% [markdown]
# _Part 1_

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
categories = ['Electronics', 'Clothing', 'Home & Kitchen', 'Sports']
sales_data = np.random.randint(1000, 5001, (12, 4))
sales_df = pd.DataFrame(sales_data, columns=categories, index=months)
print(sales_df)
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         2893      3515            3191    4558
# Feb         3983      4726            4907    1293
# Mar         2055      3239            1647    1802
# Apr         4069      2620            3187    4500
# May         4380      4100            1672    4198
# Jun         2394      3536            3036    3842
# Jul         1205      3732            2184    4314
# Aug         2536      1087            4583    1007
# Sep         2628      2068            2414    4062
# Oct         4861      2689            2009    3938
# Nov         4860      4225            2795    3530
# Dec         4843      2487            3809    3368

# %% [markdown]
# _Part 2_

# %%
print("First 5 rows","\n",sales_df.head(),"\n")
print("Summary","\n",sales_df.describe(),"\n")

total_sales_category = sales_df.sum()
print("Total sales per category\n", total_sales_category,"\n")
sales_df['Total Sales'] = sales_df.sum(axis=1)
print("Total sales per month\n", sales_df['Total Sales'])

average_growth = sales_df.pct_change().mean()
print("Average sales growth between consecutive months",average_growth,"\n")
sales_df['Growth Rate'] = sales_df['Total Sales'].pct_change() * 100

print("Percentage change in Total Sales from the previous month.:\n", sales_df['Growth Rate'])

if roll_number % 2 == 0:
    sales_df['Electronics'] *= 0.9  # 10% discount
else:
    sales_df['Clothing'] *= 0.85  # 15% discount

print("\nSales data after discount:")
print(sales_df)
# Out:
# First 5 rows
#       Electronics  Clothing  Home & Kitchen  Sports
# Jan         2893      3515            3191    4558
# Feb         3983      4726            4907    1293
# Mar         2055      3239            1647    1802
# Apr         4069      2620            3187    4500
# May         4380      4100            1672    4198
#
# Summary
#         Electronics     Clothing  Home & Kitchen       Sports
# count    12.000000    12.000000       12.000000    12.000000
# mean   3392.250000  3168.666667     2952.833333  3367.666667
# std    1255.320106  1023.641835     1064.750063  1267.463346
# min    1205.000000  1087.000000     1647.000000  1007.000000
# 25%    2500.500000  2586.750000     2140.250000  2976.500000
# 50%    3438.000000  3377.000000     2915.500000  3890.000000
# 75%    4495.750000  3824.000000     3345.500000  4227.000000
# max    4861.000000  4726.000000     4907.000000  4558.000000
#
# Total sales per category
#  Electronics       40707
# Clothing          38024
# Home & Kitchen    35434
# Sports            40412
# dtype: int64
#
# Total sales per month
#  Jan    14157
# Feb    14909
# Mar     8743
# Apr    14376
# May    14350
# Jun    12808
# Jul    11435
# Aug     9213
# Sep    11172
# Oct    13497
# Nov    15410
# Dec    14507
# Name: Total Sales, dtype: int64
# Average sales growth between consecutive months Electronics       0.180540
# Clothing          0.088675
# Home & Kitchen    0.189060
# Sports            0.293879
# Total Sales       0.034266
# dtype: float64
#
# Percentage change in Total Sales from the previous month.:
#  Jan          NaN
# Feb     5.311860
# Mar   -41.357569
# Apr    64.428686
# May    -0.180857
# Jun   -10.745645
# Jul   -10.719863
# Aug   -19.431570
# Sep    21.263432
# Oct    20.810956
# Nov    14.173520
# Dec    -5.859831
# Name: Growth Rate, dtype: float64
#
# Sales data after discount:
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan       2603.7      3515            3191    4558        14157          NaN
# Feb       3584.7      4726            4907    1293        14909     5.311860
# Mar       1849.5      3239            1647    1802         8743   -41.357569
# Apr       3662.1      2620            3187    4500        14376    64.428686
# May       3942.0      4100            1672    4198        14350    -0.180857
# Jun       2154.6      3536            3036    3842        12808   -10.745645
# Jul       1084.5      3732            2184    4314        11435   -10.719863
# Aug       2282.4      1087            4583    1007         9213   -19.431570
# Sep       2365.2      2068            2414    4062        11172    21.263432
# Oct       4374.9      2689            2009    3938        13497    20.810956
# Nov       4374.0      4225            2795    3530        15410    14.173520
# Dec       4358.7      2487            3809    3368        14507    -5.859831

# %% [markdown]
# _Part 3_

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 5))
sales_df[categories].plot(marker='o')
plt.title("Monthly Sales Trends")
plt.xlabel("Month")
plt.ylabel("Sales Units")
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(8, 5))
sns.boxplot(data=sales_df[categories])
plt.title("Sales Distribution by Category")
plt.show()

# %% [markdown]
# **Ques 2**

# %%
array = np.array([[1, -2, 3],[-4, 5, -6]])
print("Element-wise absolute:", np.abs(array))

flattened_array = array.flatten()
print("Percentiles:", np.percentile(flattened_array, [25, 50, 75]))
print("Mean:", np.mean(flattened_array))
print("Median:", np.median(flattened_array))
print("Standard Deviation:", np.std(flattened_array))
# Out:
# Element-wise absolute: [[1 2 3]
#  [4 5 6]]
# Percentiles: [-3.5 -0.5  2.5]
# Mean: -0.5
# Median: -0.5
# Standard Deviation: 3.8622100754188224

# %% [markdown]
# **Ques 3**

# %%
a = np.array([-1.8, -1.6, -0.5, 0.5,1.6, 1.8, 3.0])
print("Floor:", np.floor(a))
print("Ceiling:", np.ceil(a))
print("Truncated:", np.trunc(a))
print("Rounded:", np.round(a))
# Out:
# Floor: [-2. -2. -1.  0.  1.  1.  3.]
# Ceiling: [-1. -1. -0.  1.  2.  2.  3.]
# Truncated: [-1. -1. -0.  0.  1.  1.  3.]
# Rounded: [-2. -2. -0.  0.  2.  2.  3.]

# %% [markdown]
# **Ques 4**

# %%
def swap_list_elements(lst, idx1, idx2):
    temp = lst[idx1]
    lst[idx1] = lst[idx2]
    lst[idx2] = temp
    return lst

example_list = [13,64,78,24,8]
print("Before Swap:", example_list)
print("After Swap:", swap_list_elements(example_list, 2, 4))
# Out:
# Before Swap: [13, 64, 78, 24, 8]
# After Swap: [13, 64, 8, 24, 78]

# %% [markdown]
# **Ques 5**

# %%
example_set = {13,64,78,24,8}
example_list = list(example_set)
example_list[0], example_list[1] = example_list[1], example_list[0]
example_set = set(example_list)
print("Swapped Set:", example_set)
# Out:
# Swapped Set: {64, 8, 13, 78, 24}
